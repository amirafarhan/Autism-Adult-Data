# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Colums=["A1_Score","A2_Score","A3_Score","A4_Score","A5_Score",
        "A6_Score","A7_Score","A8_Score","A9_Score","A10_Score",
        "age","gender","ethicity","jundice","austim","country_of_res",
        "used_app_before","result","age_desc","realation","class/ASD"]
df=pd.read_csv(r"C:\Users\Admin\Downloads\Autism-Adult-Data.csv",names=Colums)
df.head()
# Out:
#    A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0         1         1         1         1         0         0         1
# 1         1         1         0         1         0         0         0
# 2         1         1         0         1         1         0         1
# 3         1         1         0         1         0         0         1
# 4         1         0         0         0         0         0         0
#
#    A8_Score  A9_Score  A10_Score  ... gender        ethicity jundice austim  \
# 0         1         0          0  ...      f  White-European      no     no
# 1         1         0          1  ...      m          Latino      no    yes
# 2         1         1          1  ...      m          Latino     yes    yes
# 3         1         0          1  ...      f  White-European      no    yes
# 4         1         0          0  ...      f               ?      no     no
#
#     country_of_res used_app_before result       age_desc realation class/ASD
# 0  'United States'              no      6  '18 and more'      Self        NO
# 1           Brazil              no      5  '18 and more'      Self        NO
# 2            Spain              no      8  '18 and more'    Parent       YES
# 3  'United States'              no      6  '18 and more'      Self        NO
# 4            Egypt              no      2  '18 and more'         ?        NO
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 704 entries, 0 to 703
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   A1_Score         704 non-null    int64
#  1   A2_Score         704 non-null    int64
#  2   A3_Score         704 non-null    int64
#  3   A4_Score         704 non-null    int64
#  4   A5_Score         704 non-null    int64
#  5   A6_Score         704 non-null    int64
#  6   A7_Score         704 non-null    int64
#  7   A8_Score         704 non-null    int64
#  8   A9_Score         704 non-null    int64
#  9   A10_Score        704 non-null    int64
#  10  age              704 non-null    object
#  11  gender           704 non-null    object
#  12  ethicity         704 non-null    object
#  13  jundice          704 non-null    object
#  14  austim           704 non-null    object
#  15  country_of_res   704 non-null    object
#  16  used_app_before  704 non-null    object
#  17  result           704 non-null    int64
#  18  age_desc         704 non-null    object
#  19  realation        704 non-null    object
#  20  class/ASD        704 non-null    object
# dtypes: int64(11), object(10)
# memory usage: 115.6+ KB

# %%
df.describe()
# Out:
#          A1_Score    A2_Score    A3_Score    A4_Score    A5_Score    A6_Score  \
# count  704.000000  704.000000  704.000000  704.000000  704.000000  704.000000
# mean     0.721591    0.453125    0.457386    0.495739    0.498580    0.284091
# std      0.448535    0.498152    0.498535    0.500337    0.500353    0.451301
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      1.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#          A7_Score    A8_Score    A9_Score   A10_Score      result
# count  704.000000  704.000000  704.000000  704.000000  704.000000
# mean     0.417614    0.649148    0.323864    0.573864    4.875000
# std      0.493516    0.477576    0.468281    0.494866    2.501493
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    3.000000
# 50%      0.000000    1.000000    0.000000    1.000000    4.000000
# 75%      1.000000    1.000000    1.000000    1.000000    7.000000
# max      1.000000    1.000000    1.000000    1.000000   10.000000

# %%
df=df.drop(["A1_Score","A2_Score","A3_Score","A4_Score","A5_Score",
        "A6_Score","A7_Score","A8_Score","A9_Score","A10_Score","age_desc","used_app_before"],axis=1)	
df.head()
# Out:
#   age gender        ethicity jundice austim   country_of_res  result  \
# 0  26      f  White-European      no     no  'United States'       6
# 1  24      m          Latino      no    yes           Brazil       5
# 2  27      m          Latino     yes    yes            Spain       8
# 3  35      f  White-European      no    yes  'United States'       6
# 4  40      f               ?      no     no            Egypt       2
#
#   realation class/ASD
# 0      Self        NO
# 1      Self        NO
# 2    Parent       YES
# 3      Self        NO
# 4         ?        NO

# %%
df = df.drop_duplicates()
df = df.reset_index(drop=True)
df
# Out:
#     age gender        ethicity jundice austim   country_of_res  result  \
# 0    26      f  White-European      no     no  'United States'       6
# 1    24      m          Latino      no    yes           Brazil       5
# 2    27      m          Latino     yes    yes            Spain       8
# 3    35      f  White-European      no    yes  'United States'       6
# 4    40      f               ?      no     no            Egypt       2
# ..   ..    ...             ...     ...    ...              ...     ...
# 658  25      f  White-European      no     no           Russia       7
# 659  34      m        Hispanic      no     no           Mexico       3
# 660  24      f               ?      no     no           Russia       7
# 661  35      m   'South Asian'      no     no         Pakistan       6
# 662  26      f  White-European      no     no           Cyprus       8
#
#     realation class/ASD
# 0        Self        NO
# 1        Self        NO
# 2      Parent       YES
# 3        Self        NO
# 4           ?        NO
# ..        ...       ...
# 658      Self       YES
# 659    Parent        NO
# 660         ?       YES
# 661      Self        NO
# 662      Self       YES
#
# [663 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# age               0
# gender            0
# ethicity          0
# jundice           0
# austim            0
# country_of_res    0
# result            0
# realation         0
# class/ASD         0
# dtype: int64

# %%
import numpy as np


df.replace('?', np.nan, inplace=True)
df
# Out:
#     age gender        ethicity jundice austim   country_of_res  result  \
# 0    26      f  White-European      no     no  'United States'       6
# 1    24      m          Latino      no    yes           Brazil       5
# 2    27      m          Latino     yes    yes            Spain       8
# 3    35      f  White-European      no    yes  'United States'       6
# 4    40      f             NaN      no     no            Egypt       2
# ..   ..    ...             ...     ...    ...              ...     ...
# 658  25      f  White-European      no     no           Russia       7
# 659  34      m        Hispanic      no     no           Mexico       3
# 660  24      f             NaN      no     no           Russia       7
# 661  35      m   'South Asian'      no     no         Pakistan       6
# 662  26      f  White-European      no     no           Cyprus       8
#
#     realation class/ASD
# 0        Self        NO
# 1        Self        NO
# 2      Parent       YES
# 3        Self        NO
# 4         NaN        NO
# ..        ...       ...
# 658      Self       YES
# 659    Parent        NO
# 660       NaN       YES
# 661      Self        NO
# 662      Self       YES
#
# [663 rows x 9 columns]

# %%
df.isna().sum()
# Out:
# age                2
# gender             0
# ethicity          88
# jundice            0
# austim             0
# country_of_res     0
# result             0
# realation         88
# class/ASD          0
# dtype: int64

# %%
df['age'] = pd.to_numeric(df['age'], errors='coerce')
df=df[df["age"]<80]
df
# Out:
#       age gender        ethicity jundice austim   country_of_res  result  \
# 0    26.0      f  White-European      no     no  'United States'       6
# 1    24.0      m          Latino      no    yes           Brazil       5
# 2    27.0      m          Latino     yes    yes            Spain       8
# 3    35.0      f  White-European      no    yes  'United States'       6
# 4    40.0      f             NaN      no     no            Egypt       2
# ..    ...    ...             ...     ...    ...              ...     ...
# 658  25.0      f  White-European      no     no           Russia       7
# 659  34.0      m        Hispanic      no     no           Mexico       3
# 660  24.0      f             NaN      no     no           Russia       7
# 661  35.0      m   'South Asian'      no     no         Pakistan       6
# 662  26.0      f  White-European      no     no           Cyprus       8
#
#     realation class/ASD
# 0        Self        NO
# 1        Self        NO
# 2      Parent       YES
# 3        Self        NO
# 4         NaN        NO
# ..        ...       ...
# 658      Self       YES
# 659    Parent        NO
# 660       NaN       YES
# 661      Self        NO
# 662      Self       YES
#
# [660 rows x 9 columns]

# %%
df["realation"]=df["realation"].fillna(df["realation"].mode()[0])
df["ethicity"]=df["ethicity"].fillna(df["ethicity"].mode()[0])
df
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_21136\1976095724.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["realation"]=df["realation"].fillna(df["realation"].mode()[0])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_21136\1976095724.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ethicity"]=df["ethicity"].fillna(df["ethicity"].mode()[0])
#       age gender        ethicity jundice austim   country_of_res  result  \
# 0    26.0      f  White-European      no     no  'United States'       6
# 1    24.0      m          Latino      no    yes           Brazil       5
# 2    27.0      m          Latino     yes    yes            Spain       8
# 3    35.0      f  White-European      no    yes  'United States'       6
# 4    40.0      f  White-European      no     no            Egypt       2
# ..    ...    ...             ...     ...    ...              ...     ...
# 658  25.0      f  White-European      no     no           Russia       7
# 659  34.0      m        Hispanic      no     no           Mexico       3
# 660  24.0      f  White-European      no     no           Russia       7
# 661  35.0      m   'South Asian'      no     no         Pakistan       6
# 662  26.0      f  White-European      no     no           Cyprus       8
#
#     realation class/ASD
# 0        Self        NO
# 1        Self        NO
# 2      Parent       YES
# 3        Self        NO
# 4        Self        NO
# ..        ...       ...
# 658      Self       YES
# 659    Parent        NO
# 660      Self       YES
# 661      Self        NO
# 662      Self       YES
#
# [660 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# age               0
# gender            0
# ethicity          0
# jundice           0
# austim            0
# country_of_res    0
# result            0
# realation         0
# class/ASD         0
# dtype: int64

# %%
df["country_of_res"] = df["country_of_res"].astype(str).str.lower().str.replace("'", "", regex=False).str.strip()
df["ethicity"] = df["ethicity"].astype(str).str.lower().str.replace("'", "", regex=False).str.strip()
df
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_21136\3011029431.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["country_of_res"] = df["country_of_res"].astype(str).str.lower().str.replace("'", "", regex=False).str.strip()
# C:\Users\Admin\AppData\Local\Temp\ipykernel_21136\3011029431.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ethicity"] = df["ethicity"].astype(str).str.lower().str.replace("'", "", regex=False).str.strip()
#       age gender        ethicity jundice austim country_of_res  result  \
# 0    26.0      f  white-european      no     no  united states       6
# 1    24.0      m          latino      no    yes         brazil       5
# 2    27.0      m          latino     yes    yes          spain       8
# 3    35.0      f  white-european      no    yes  united states       6
# 4    40.0      f  white-european      no     no          egypt       2
# ..    ...    ...             ...     ...    ...            ...     ...
# 658  25.0      f  white-european      no     no         russia       7
# 659  34.0      m        hispanic      no     no         mexico       3
# 660  24.0      f  white-european      no     no         russia       7
# 661  35.0      m     south asian      no     no       pakistan       6
# 662  26.0      f  white-european      no     no         cyprus       8
#
#     realation class/ASD
# 0        Self        NO
# 1        Self        NO
# 2      Parent       YES
# 3        Self        NO
# 4        Self        NO
# ..        ...       ...
# 658      Self       YES
# 659    Parent        NO
# 660      Self       YES
# 661      Self        NO
# 662      Self       YES
#
# [660 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 660 entries, 0 to 662
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             660 non-null    float64
#  1   gender          660 non-null    object
#  2   ethicity        660 non-null    object
#  3   jundice         660 non-null    object
#  4   austim          660 non-null    object
#  5   country_of_res  660 non-null    object
#  6   result          660 non-null    int64
#  7   realation       660 non-null    object
#  8   class/ASD       660 non-null    object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 51.6+ KB

# %%
df.isnull().sum()
# Out:
# age               0
# gender            0
# ethicity          0
# jundice           0
# austim            0
# country_of_res    0
# result            0
# realation         0
# class/ASD         0
# dtype: int64

# %%
df.describe()
# Out:
#               age      result
# count  660.000000  660.000000
# mean    29.428788    4.927273
# std      9.806137    2.523489
# min     17.000000    0.000000
# 25%     22.000000    3.000000
# 50%     27.000000    4.000000
# 75%     35.000000    7.000000
# max     64.000000   10.000000

# %%
df
# Out:
#       age gender        ethicity jundice austim country_of_res  result  \
# 0    26.0      f  white-european      no     no  united states       6
# 1    24.0      m          latino      no    yes         brazil       5
# 2    27.0      m          latino     yes    yes          spain       8
# 3    35.0      f  white-european      no    yes  united states       6
# 4    40.0      f  white-european      no     no          egypt       2
# ..    ...    ...             ...     ...    ...            ...     ...
# 658  25.0      f  white-european      no     no         russia       7
# 659  34.0      m        hispanic      no     no         mexico       3
# 660  24.0      f  white-european      no     no         russia       7
# 661  35.0      m     south asian      no     no       pakistan       6
# 662  26.0      f  white-european      no     no         cyprus       8
#
#     realation class/ASD
# 0        Self        NO
# 1        Self        NO
# 2      Parent       YES
# 3        Self        NO
# 4        Self        NO
# ..        ...       ...
# 658      Self       YES
# 659    Parent        NO
# 660      Self       YES
# 661      Self        NO
# 662      Self       YES
#
# [660 rows x 9 columns]

# %%
groups=df.groupby("age")["result"].sum()
plt.plot(groups.index,groups.values);

# %%
sns.barplot(x="realation",y="austim",data=df);

# %%
top_ethicity = df.groupby('ethicity')['result'].sum()
top_ethicity=top_ethicity.sort_values(ascending=False)
top_ethicity=top_ethicity.head(5)
plt.style.use("ggplot")
plt.pie(top_ethicity.values, labels=top_ethicity.index, autopct='%1.1f%%');

# %%
sns.countplot(x='class/ASD', hue='result', data=df)
# Out:
# <Axes: xlabel='class/ASD', ylabel='count'>

# %%
sns.countplot(x='jundice', hue='age', data=df)
# Out:
# <Axes: xlabel='jundice', ylabel='count'>

# %%
top_country_of_res = df.groupby('country_of_res')['result'].sum()
top_country_of_res=top_country_of_res.sort_values(ascending=False)
top_country_of_res=top_country_of_res.head(5)
plt.style.use("ggplot")
plt.pie(top_country_of_res.values, labels=top_country_of_res.index, autopct='%1.1f%%');

# %%
sns.countplot(data=df,x="realation",hue='class/ASD')
# Out:
# <Axes: xlabel='realation', ylabel='count'>

# %%
sns.countplot(data=df,x="gender",hue='austim')
# Out:
# <Axes: xlabel='gender', ylabel='count'>
